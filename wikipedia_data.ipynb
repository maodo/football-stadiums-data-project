# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from geopy import Nominatim

# %%
url ='https://en.wikipedia.org/wiki/List_of_association_football_stadiums_by_capacity'
NO_IMAGE = 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0a/No-image-available.png/480px-No-image-available.png'

# %%
def get_html_page(url):
    print(f'Getting wikipedia html page {url}')
    try:
        response = requests.get(url,timeout=10)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.RequestException as e:
        print(f'Error getting wikipedia data {e}')

# %%
def get_table_data(url):
    soup = get_html_page(url)
    table = soup.find_all("table", {"class":"wikitable"})[1]
    table_rows = table.find_all("tr")
    return table_rows

# %%
def get_geo_loc(country, city):
    geolocator = Nominatim(user_agent='geoapiExercises')
    location = geolocator.geocode(f'{city}, {country}')
    if location:
        return location.latitude, location.longitude
    return None

# %%
data = []
def extract_data(url):
    table_rows = get_table_data(url)
    for i in range(1,len(table_rows)):
        table_data = table_rows[i].find_all('td')
    
        description_url = 'https://en.m.wikipedia.org' + table_data[0].find('a').get('href')
        desc_html = get_html_page(description_url)
        section_content = desc_html.find_all("section",{"class":"mf-section-0"})
        if section_content:
            p_len = len(section_content[0].find_all("p"))
            if p_len == 1:
                description = section_content[0].find_all("p")[0].text
            elif p_len == 2:
                description = section_content[0].find_all("p")[1].text
            elif p_len > 2:
                description = section_content[0].find_all("p")[1].text + "-" + section_content[0].find_all("p")[2].text
        else :
            description = 'No description available for this stadium'
            
        table_values = {
            'rank' : i,
            'stadium' : table_data[0].text,
            'description' : description,
            'capacity' : table_data[1].text,
            'region' : table_data[2].text,
            'country' : table_data[3].text,
            'city' : table_data[4].text,
            'home_team' : table_data[6].text,
            'image_url' : 'https:' + table_data[5].find('img').get('src') if table_data[5].find('img') else NO_IMAGE
        }
        data.append(table_values)
    return pd.DataFrame(data)

# %%
df_stadiums = extract_data(url)
# Out:
# Getting wikipedia html page https://en.wikipedia.org/wiki/List_of_association_football_stadiums_by_capacity
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Rungrado_1st_of_May_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Michigan_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Ohio_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Melbourne_Cricket_Ground
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Camp_Nou
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Azteca
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/FNB_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/New_Administrative_Capital_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Rose_Bowl_(stadium)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Cotton_Bowl_(stadium)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Wembley_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Lusail_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Bukit_Jalil_National_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Borg_El_Arab_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Santiago_Bernab%C3%A9u_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Monumental_Antonio_Vespucio_Liberti
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stadium_Australia
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/MetLife_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Croke_Park
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Jakarta_International_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Lambeau_Field
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Westfalenstadion
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stade_de_France
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Luzhniki_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Shah_Alam_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Monumental_%22U%22
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/San_Siro
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Guangdong_Olympic_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Hangzhou_Olympic_Sports_Expo_Center
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/AT%26T_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stade_des_Martyrs
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stade_Tata_Rapha%C3%ABl
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/National_Sports_Stadium_(Zimbabwe)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Moi_International_Sports_Centre
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Beijing_National_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stade_L%C3%A9opold_S%C3%A9dar_Senghor
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Maracan%C3%A3_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Los_Angeles_Memorial_Coliseum
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Azadi_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Gelora_Bung_Karno_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Caesars_Superdome
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Arrowhead_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Empower_Field_at_Mile_High
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Atat%C3%BCrk_Olympic_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Old_Trafford
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Allianz_Arena
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Naghsh-e-Jahan_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Bank_of_America_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Millennium_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Olympiastadion_(Berlin)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Cairo_International_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/FirstEnergy_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Est%C3%A1dio_Nacional_Man%C3%A9_Garrincha
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stadio_Olimpico
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/International_Stadium_Yokohama
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/NRG_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Shanghai_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/M%26T_Bank_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Mercedes-Benz_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Olimpiyskiy_National_Sports_Complex
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/SoFi_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Seoul_Olympic_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Baku_Olympic_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Olympic_Stadium_(Athens)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Olympiastadion_(Munich)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Lumen_Field
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Ol%C3%ADmpico_Universitario
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stage_Front_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Metropolitano_de_F%C3%BAtbol_de_Lara
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Malvinas_Argentinas
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Lukas_Enembe_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Gwangju_World_Cup_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/M%E1%BB%B9_%C4%90%C3%ACnh_National_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Goodison_Park
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Castel%C3%A3o_(Maranh%C3%A3o)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Miloud_Hadefi_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Estadio_Campe%C3%B3n_del_Siglo
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Metalist_Oblast_Sports_Complex
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Al_Janoub_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Al_Thumama_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Ahmed_Zabana_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Batakan_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Gelora_Joko_Samudro_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Fisht_Olympic_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Rentschler_Field_(stadium)
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Jawaharlal_Nehru_Stadium,_Kochi
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Hang_Jebat_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Hong_Kong_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Negeri_Pulau_Pinang_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Accra_Sports_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Sarawak_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Bogyoke_Aung_San_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Resonac_Dome_Oita
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Darul_Makmur_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Khalifa_International_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Stade_d%27Angondj%C3%A9
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Peoples_Football_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/JRD_Tata_Sports_Complex
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Bao%27an_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Kunming_Tuodong_Sports_Center
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Taizhou_Sports_Center
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Wuhu_Olympic_Stadium
# Getting wikipedia html page https://en.m.wikipedia.org/wiki/Huizhou_Olympic_Stadium

# %%
df_stadiums.to_csv('./data/output.csv', index=False)

# %%
df = pd.read_csv('./data/output.csv')

# %%
import re
def handle_capacity(text):
    cleaned = re.sub("[\(\[].*?[\)\]]", "", text)
    cleaned_text = cleaned.replace(",","")
    return cleaned_text

# %%
def transform_data(data: pd.DataFrame):
    data['capacity'] = data['capacity'].apply(lambda x: handle_capacity(x))
    data['city'] = data['city'].apply(lambda x: x.strip())
    data['country'] = data['country'].apply(lambda x: x.strip())
    data['home_team'] = data['home_team'].apply(lambda x: x.strip())
    data['stadium'] = data['stadium'].apply(lambda x: x.replace("♦","").strip())
    data['capacity'] = data['capacity'].astype(int)
    data['description'] = data['description'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x))
    data['description'] = data['description'].apply(lambda x: x.replace('\n',' ').strip())
    #data['location'] = data.apply(lambda x: get_geo_loc(x['country'],x['city']), axis=1 )
    return data

# %%
transformed_data = transform_data(df)

# %%
transformed_data.head()
# Out:
#    rank                      stadium  \
# 0     1  Rungrado 1st of May Stadium
# 1     2             Michigan Stadium
# 2     3                 Ohio Stadium
# 3     4     Melbourne Cricket Ground
# 4     5                     Camp Nou
#
#                                          description  capacity         region  \
# 0  The Rungrado 1st of May Stadium is a multi-pur...    114000      East Asia
# 1  Formerly -Michigan Stadium was built in 1927 a...    107601  North America
# 2  Ohio Stadium is an American football stadium i...    102780  North America
# 3  The  Melbourne Cricket Ground , also known loc...    100024        Oceania
# 4  -Camp Nou , meaning New Field, often referred ...     99354         Europe
#
#          country                  city  \
# 0    North Korea             Pyongyang
# 1  United States   Ann Arbor, Michigan
# 2  United States        Columbus, Ohio
# 3      Australia   Melbourne, Victoria
# 4          Spain  Barcelona, Catalonia
#
#                                            home_team  \
# 0  Korea DPR national football team, Korea DPR wo...
# 1                       Michigan Wolverines football
# 2                       Ohio State Buckeyes football
# 3  Australia national cricket team, Victoria cric...
# 4                                       FC Barcelona
#
#                                            image_url
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...
